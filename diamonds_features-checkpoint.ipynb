# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib  inline
import seaborn as sns

# %%
import os 
os.chdir('C:/DBAR')
df=pd.read_csv('expensive_diamonds.csv')

# %%
df.shape
# Out:
# (39416, 10)

# %% [markdown]
# ##Features
# Carat : Carat weight of the Diamond.
#
#
#
# Cut : Describe cut quality of the diamond.
#
#
# Quality in increasing order Fair, Good, Very Good, Premium, Ideal .
#
#
# Color : Color of the Diamond.
#
# With D being the best and J the worst.
#
#
# Clarity : Diamond Clarity refers to the absence of the Inclusions and Blemishes.
# (In order from Best to Worst, FL = flawless, I3= level 3 inclusions) FL, IF, VVS1, VVS2, VS1, VS2, SI1, SI2, I1, I2, I3
#
#
# Depth : The Height of a Diamond, measured from the Culet to the table, divided by its average Girdle Diameter.
#
#
# Table : The Width of the Diamond's Table expressed as a Percentage of its Average Diameter.
#
#
# Price : the Price of the Diamond.
#
# X : Length of the Diamond in mm.
# Y : Width of the Diamond in mm.
# Z : Height of the Diamond in mm.

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.70      Ideal     E     SI1   62.5   57.0   2757  5.70  5.72  3.57
# 1   0.86       Fair     E     SI2   55.1   69.0   2757  6.45  6.33  3.52
# 2   0.70      Ideal     G     VS2   61.6   56.0   2757  5.70  5.67  3.50
# 3   0.71  Very Good     E     VS2   62.4   57.0   2759  5.68  5.73  3.56
# 4   0.78  Very Good     G     SI2   63.8   56.0   2759  5.81  5.85  3.72

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
sns.pairplot(df)

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  39416.000000  39416.000000  39416.000000  39416.000000  39416.000000
# mean       0.968547     61.748742     57.637348   5120.931475      6.202895
# std        0.445358      1.520192      2.260743   4065.451335      0.935887
# min        0.250000     43.000000     43.000000   1001.000000      0.000000
# 25%        0.600000     61.000000     56.000000   2028.750000      5.430000
# 50%        0.920000     61.800000     57.000000   3920.000000      6.230000
# 75%        1.190000     62.600000     59.000000   6708.000000      6.770000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  39416.000000  39416.000000
# mean       6.203048      3.828653
# std        0.974945      0.601154
# min        0.000000      0.000000
# 25%        5.450000      3.340000
# 50%        6.230000      3.860000
# 75%        6.760000      4.180000
# max       58.900000     31.800000

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df.loc[(df['x']==0) | (df['y']==0) | (df['z']==0)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 1937    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2044    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4251    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 4871    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 9087    1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 10012   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 10733   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 12191   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 14331   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 21904   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 22030   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# 23483   2.25    Premium     I     SI1   61.3   58.0  15397  8.52  8.42  0.0
# 23603   1.20    Premium     D    VVS1   62.1   59.0  15686  0.00  0.00  0.0
# 24352   2.20    Premium     H     SI1   61.2   59.0  17265  8.42  8.37  0.0
# 24639   2.25    Premium     H     SI2   62.8   59.0  18034  0.00  0.00  0.0
# 24713   2.02    Premium     H     VS2   62.7   53.0  18207  8.02  7.95  0.0
# 24919   2.80       Good     G     SI2   63.8   58.0  18788  8.90  8.85  0.0
# 35452   0.71       Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 35453   0.71       Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 37192   1.12    Premium     G      I1   60.4   59.0   2383  6.71  6.67  0.0

# %%
len(df[(df['x']==0) | (df['y']==0) | (df['z']==0)])
# Out:
# 20

# %%
df = df[(df[['x','y','z']] != 0).all(axis=1)]

# %%
df.loc[(df['x']==0) | (df['y']==0) | (df['z']==0)]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
corr = df.corr()
sns.heatmap(data=corr, square=True , annot=True, cbar=True)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.factorplot(x='cut', data=df , kind='count',aspect=2.5 )

# %%
sns.factorplot(x='color', data=df , kind='count',aspect=2.5 )

# %%
sns.boxplot(x='clarity', y='price', data=df )

# %%
plt.hist('depth' , data=df , bins=20)
# Out:
# (array([3.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         9.0000e+00, 2.4000e+01, 2.1000e+02, 1.7040e+03, 7.5500e+03,
#         2.2004e+04, 6.7650e+03, 8.5700e+02, 1.9200e+02, 5.5000e+01,
#         1.5000e+01, 3.0000e+00, 1.0000e+00, 0.0000e+00, 3.0000e+00]),
#  array([43. , 44.8, 46.6, 48.4, 50.2, 52. , 53.8, 55.6, 57.4, 59.2, 61. ,
#         62.8, 64.6, 66.4, 68.2, 70. , 71.8, 73.6, 75.4, 77.2, 79. ]),
#  <a list of 20 Patch objects>)

# %%
df['volume'] = df['x']*df['y']*df['z']
df.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.70      Ideal     E     SI1   62.5   57.0   2757  5.70  5.72  3.57
# 1   0.86       Fair     E     SI2   55.1   69.0   2757  6.45  6.33  3.52
# 2   0.70      Ideal     G     VS2   61.6   56.0   2757  5.70  5.67  3.50
# 3   0.71  Very Good     E     VS2   62.4   57.0   2759  5.68  5.73  3.56
# 4   0.78  Very Good     G     SI2   63.8   56.0   2759  5.81  5.85  3.72
#
#        volume
# 0  116.396280
# 1  143.716320
# 2  113.116500
# 3  115.865184
# 4  126.437220

# %%
## price per carat
df['price_per_carat']=df['carat']*df['price']
df.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.70      Ideal     E     SI1   62.5   57.0   2757  5.70  5.72  3.57
# 1   0.86       Fair     E     SI2   55.1   69.0   2757  6.45  6.33  3.52
# 2   0.70      Ideal     G     VS2   61.6   56.0   2757  5.70  5.67  3.50
# 3   0.71  Very Good     E     VS2   62.4   57.0   2759  5.68  5.73  3.56
# 4   0.78  Very Good     G     SI2   63.8   56.0   2759  5.81  5.85  3.72
#
#        volume  price_per_carat
# 0  116.396280          1929.90
# 1  143.716320          2371.02
# 2  113.116500          1929.90
# 3  115.865184          1958.89
# 4  126.437220          2152.02

# %%
df.plot.scatter('carat','price_per_carat')

# %%
x=df.drop(['price'],axis=1)
y=df['price']
x.shape,y.shape
# Out:
# ((39396, 11), (39396,))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x, y, random_state = 60, test_size=0.3)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_cut = LabelEncoder()
label_color = LabelEncoder()
label_clarity = LabelEncoder()


df['cut'] = label_cut.fit_transform(df['cut'])
df['color'] = label_color.fit_transform(df['color'])
df['clarity'] = label_clarity.fit_transform(df['clarity'])

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z  \
# 0   0.70    2      1        2   62.5   57.0   2757  5.70  5.72  3.57
# 1   0.86    0      1        3   55.1   69.0   2757  6.45  6.33  3.52
# 2   0.70    2      3        5   61.6   56.0   2757  5.70  5.67  3.50
# 3   0.71    4      1        5   62.4   57.0   2759  5.68  5.73  3.56
# 4   0.78    4      3        3   63.8   56.0   2759  5.81  5.85  3.72
#
#        volume  price_per_carat
# 0  116.396280          1929.90
# 1  143.716320          2371.02
# 2  113.116500          1929.90
# 3  115.865184          1958.89
# 4  126.437220          2152.02

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler_df=scaler.fit_transform(df)

# %%
from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import mean_absolute_error as mae

# %%
lr = LR()

# Fitting the model
lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
train_predict = lr.predict(x_train)
k = mae(train_predict, y_train)
print('Training Mean Absolute Error', k )
# Out:
# Training Mean Absolute Error 466.67010634754973

# %%
valid_predict = lr.predict(x_valid)
k = mae(valid_predict, y_valid)
print('Test Mean Absolute Error    ', k )
# Out:
# Test Mean Absolute Error     463.44360753462666

# %%
from sklearn.metrics import r2_score
R2=r2_score(y_valid,valid_predict)
print('R Squared: {}'.format(R2))
# Out:
# R Squared: 0.9761514872824129

# %%
# Arranging and calculating the Residuals
residuals = pd.DataFrame({
    'fitted values' : y_valid,
    'predicted values' : valid_predict,
})

residuals['residuals'] = residuals['fitted values'] - residuals['predicted values']
residuals.head()
# Out:
#        fitted values  predicted values   residuals
# 1823            3113       3433.673154 -320.673154
# 6599            4223       4248.910511  -25.910511
# 28404           1241        955.634979  285.365021
# 7906            4478       4953.190758 -475.190758
# 35529           2141       2785.926158 -644.926158

# %%
# Histogram for distribution
plt.figure(figsize=(10, 6), dpi=120, facecolor='w', edgecolor='b')
plt.hist(residuals.residuals, bins = 150)
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.title('Distribution of Error Terms')
plt.show()

# %% [markdown]
# ## QQ-plot (Is it normally distributed)

# %%
# importing the QQ-plot from the from the statsmodels
from statsmodels.graphics.gofplots import qqplot

## Plotting the QQ plot
fig, ax = plt.subplots(figsize=(5,5) , dpi = 120)
qqplot(residuals.residuals, line = 's' , ax = ax)
plt.ylabel('Residual Quantiles')
plt.xlabel('Ideal Scaled Quantiles')
plt.title('Checking distribution of Residual Errors')
plt.show()

# %%
lr.coef_
# Out:
# array([-9.99285456e+03,  9.36115916e+00, -1.15004075e+02,  1.39498798e+02,
#         1.97384094e+02, -4.61613390e+00,  4.27672112e+03,  1.40474120e+03,
#         7.30883196e+02, -2.32583260e+01,  5.70117228e-01])

# %%
Coefficients = pd.DataFrame({
    'Variable'    : x.columns,
    'coefficient' : lr.coef_
})
Coefficients.head(12)
# Out:
#            Variable  coefficient
# 0             carat -9992.854559
# 1               cut     9.361159
# 2             color  -115.004075
# 3           clarity   139.498798
# 4             depth   197.384094
# 5             table    -4.616134
# 6                 x  4276.721117
# 7                 y  1404.741203
# 8                 z   730.883196
# 9            volume   -23.258326
# 10  price_per_carat     0.570117
